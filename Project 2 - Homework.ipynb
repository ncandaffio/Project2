# %%
import pandas as pd
from sqlalchemy import create_engine
import requests
import warnings
warnings.filterwarnings('ignore')

# %%
f = "airbnb-listings.csv"
f_df = pd.read_csv(f, delimiter=';', encoding = 'latin-1')
f_df.head()
# Out:
#          ID                            Listing Url       Scrape ID  \
# 0   2501888   https://www.airbnb.com/rooms/2501888  20170306202425
# 1    377609    https://www.airbnb.com/rooms/377609  20170306202425
# 2  15643010  https://www.airbnb.com/rooms/15643010  20170306202425
# 3   2236988   https://www.airbnb.com/rooms/2236988  20170306202425
# 4  14788276  https://www.airbnb.com/rooms/14788276  20170306202425
#
#   Last Scraped                                               Name  \
# 0   2017-03-07                                Private bed in home
# 1   2017-03-07                     Lake House minutes to Downtown
# 2   2017-03-07          Modern New Apartment Close to Everything!
# 3   2017-03-07                          Austin Waterfront Retreat
# 4   2017-03-07  Stay at the Domain's hotest residencial property.
#
#                                              Summary  \
# 0  Sofa bed in the media room on the first floor....
# 1                                                NaN
# 2  Close to the Barton Creek Greenbelt, S Lamar, ...
# 3  Magnificent Austin waterfront home on Barton C...
# 4  Find indulgence the moment you enter the bouti...
#
#                                                Space  \
# 0  Modernist home with a strong influence from MC...
# 1  Located just 7 minutes to Downtown, and 4 minu...
# 2                                                NaN
# 3  Retreat within the city of Austin.  12 minutes...
# 4                                                NaN
#
#                                          Description Experiences Offered  \
# 0  Sofa bed in the media room on the first floor....                none
# 1  Located just 7 minutes to Downtown, and 4 minu...                none
# 2  Close to the Barton Creek Greenbelt, S Lamar, ...                none
# 3  Magnificent Austin waterfront home on Barton C...                none
# 4  Find indulgence the moment you enter the bouti...                none
#
#                                Neighborhood Overview  \
# 0  Upscale area of West Lake Hills on a bluff ove...
# 1                                                NaN
# 2                                                NaN
# 3  Quiet neighborhood tucked away in Austin.  Min...
# 4                                                NaN
#
#                          ...                          \
# 0                        ...
# 1                        ...
# 2                        ...
# 3                        ...
# 4                        ...
#
#   Review Scores Communication Review Scores Location Review Scores Value  \
# 0                        10.0                    9.0                 9.0
# 1                        10.0                   10.0                 9.0
# 2                        10.0                   10.0                10.0
# 3                        10.0                   10.0                10.0
# 4                        10.0                   10.0                 9.0
#
#   License Jurisdiction Names Cancellation Policy  \
# 0     NaN                NaN            flexible
# 1     NaN                NaN              strict
# 2     NaN                NaN            moderate
# 3     NaN                NaN              strict
# 4     NaN                NaN            moderate
#
#   Calculated host listings count Reviews per Month  \
# 0                              1              2.42
# 1                              1              0.54
# 2                              1              1.86
# 3                              1              0.21
# 4                              1              0.69
#
#                      Geolocation  \
# 0  30.2863434604, -97.8104775775
# 1  30.3028051776, -97.7942255855
# 2  30.2521539737, -97.7995481364
# 3   30.2752712576, -97.843114474
# 4  30.4001335924, -97.7241364202
#
#                                             Features
# 0  Host Has Profile Pic,Host Identity Verified,Is...
# 1  Host Has Profile Pic,Host Identity Verified,Is...
# 2  Host Has Profile Pic,Host Identity Verified,Is...
# 3             Host Has Profile Pic,Is Location Exact
# 4             Host Has Profile Pic,Is Location Exact
#
# [5 rows x 89 columns]

# %%
f_df.columns
# Out:
# Index(['ID', 'Listing Url', 'Scrape ID', 'Last Scraped', 'Name', 'Summary',
#        'Space', 'Description', 'Experiences Offered', 'Neighborhood Overview',
#        'Notes', 'Transit', 'Access', 'Interaction', 'House Rules',
#        'Thumbnail Url', 'Medium Url', 'Picture Url', 'XL Picture Url',
#        'Host ID', 'Host URL', 'Host Name', 'Host Since', 'Host Location',
#        'Host About', 'Host Response Time', 'Host Response Rate',
#        'Host Acceptance Rate', 'Host Thumbnail Url', 'Host Picture Url',
#        'Host Neighbourhood', 'Host Listings Count',
#        'Host Total Listings Count', 'Host Verifications', 'Street',
#        'Neighbourhood', 'Neighbourhood Cleansed',
#        'Neighbourhood Group Cleansed', 'City', 'State', 'Zipcode', 'Market',
#        'Smart Location', 'Country Code', 'Country', 'Latitude', 'Longitude',
#        'Property Type', 'Room Type', 'Accommodates', 'Bathrooms', 'Bedrooms',
#        'Beds', 'Bed Type', 'Amenities', 'Square Feet', 'Price', 'Weekly Price',
#        'Monthly Price', 'Security Deposit', 'Cleaning Fee', 'Guests Included',
#        'Extra People', 'Minimum Nights', 'Maximum Nights', 'Calendar Updated',
#        'Has Availability', 'Availability 30', 'Availability 60',
#        'Availability 90', 'Availability 365', 'Calendar last Scraped',
#        'Number of Reviews', 'First Review', 'Last Review',
#        'Review Scores Rating', 'Review Scores Accuracy',
#        'Review Scores Cleanliness', 'Review Scores Checkin',
#        'Review Scores Communication', 'Review Scores Location',
#        'Review Scores Value', 'License', 'Jurisdiction Names',
#        'Cancellation Policy', 'Calculated host listings count',
#        'Reviews per Month', 'Geolocation', 'Features'],
#       dtype='object')

# %%
n_df = f_df[[
    'Name','Street',
    'City', 'State', 'Zipcode','Property Type', 
    'Review Scores Rating']].copy()
n_df.head()
# Out:
#                                                 Name  \
# 0                                Private bed in home
# 1                     Lake House minutes to Downtown
# 2          Modern New Apartment Close to Everything!
# 3                          Austin Waterfront Retreat
# 4  Stay at the Domain's hotest residencial property.
#
#                                               Street             City State  \
# 0  Buckeye Trail, West Lake Hills, TX 78746, Unit...  West Lake Hills    TX
# 1       Westlake Dr, Austin, TX 78746, United States           Austin    TX
# 2  South MoPac Expressway, Austin, TX 78746, Unit...           Austin    TX
# 3  Bend O River Drive, Austin, TX 78746, United S...           Austin    TX
# 4  Esperanza Crossing, Austin, TX 78758, United S...           Austin    TX
#
#   Zipcode Property Type  Review Scores Rating
# 0   78746         Other                  94.0
# 1   78746         House                  96.0
# 2   78746     Apartment                  97.0
# 3   78746         House                  96.0
# 4   78758   Condominium                  93.0

# %%
n_df.rename(columns={'Zipcode':'Zip',
                     'Property Type':'Type',
                     'Number of Reviews':'Review Count',
                     'Street':'Address',
                     'Review Scores Rating':'Average Rating'}, 
                 inplace=True)

# %%
d = n_df.dropna()

# %%
d['State'] = d['State'].str.upper()

# %%
d.State.unique()
#
# Out:
# array(['TX', 'MA', 'CO', 'IL', 'NY', 'CA', 'LA', 'TN', 'OR', 'WA', 'MP',
#        'DC', 'MD'], dtype=object)

# %%
#d = d.set_index('Name')

# %%
d['Ratings2'] = d['Average Rating'] * (5/100)

# %%
d = d.drop(['Average Rating'],axis=1)
d.rename(columns={'Ratings2':'Average Rating'}, 
                 inplace=True)
d.head()
# Out:
#                                                 Name  \
# 0                                Private bed in home
# 1                     Lake House minutes to Downtown
# 2          Modern New Apartment Close to Everything!
# 3                          Austin Waterfront Retreat
# 4  Stay at the Domain's hotest residencial property.
#
#                                              Address             City State  \
# 0  Buckeye Trail, West Lake Hills, TX 78746, Unit...  West Lake Hills    TX
# 1       Westlake Dr, Austin, TX 78746, United States           Austin    TX
# 2  South MoPac Expressway, Austin, TX 78746, Unit...           Austin    TX
# 3  Bend O River Drive, Austin, TX 78746, United S...           Austin    TX
# 4  Esperanza Crossing, Austin, TX 78758, United S...           Austin    TX
#
#      Zip         Type  Average Rating
# 0  78746        Other            4.70
# 1  78746        House            4.80
# 2  78746    Apartment            4.85
# 3  78746        House            4.80
# 4  78758  Condominium            4.65

# %%
database_path = "db5.sqlite"
engine2 = create_engine(f"sqlite:///{database_path}")
# Query All Records in the the Database
d.to_sql(name='airbnb', con=engine2, if_exists='append', index=False)
data = engine2.execute("SELECT * FROM airbnb")

#for record in data:
 #   print(record)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\Anaconda3\envs\pythondata\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1223                     self.dialect.do_executemany(
# -> 1224                         cursor, statement, parameters, context
#    1225                     )
#
# ~\Anaconda3\envs\pythondata\lib\site-packages\sqlalchemy\engine\default.py in do_executemany(self, cursor, statement, parameters, context)
#     548     def do_executemany(self, cursor, statement, parameters, context=None):
# --> 549         cursor.executemany(statement, parameters)
#     550
#
# OperationalError: table airbnb has no column named Address
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-13-cd001299b0dd> in <module>
#       2 engine2 = create_engine(f"sqlite:///{database_path}")
#       3 # Query All Records in the the Database
# ----> 4 d.to_sql(name='airbnb', con=engine2, if_exists='append', index=False)
#       5 data = engine2.execute("SELECT * FROM airbnb")
#       6
#
# ~\Anaconda3\envs\pythondata\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype)
#    2128         sql.to_sql(self, name, con, schema=schema, if_exists=if_exists,
#    2129                    index=index, index_label=index_label, chunksize=chunksize,
# -> 2130                    dtype=dtype)
#    2131
#    2132     def to_pickle(self, path, compression='infer',
#
# ~\Anaconda3\envs\pythondata\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype)
#     448     pandas_sql.to_sql(frame, name, if_exists=if_exists, index=index,
#     449                       index_label=index_label, schema=schema,
# --> 450                       chunksize=chunksize, dtype=dtype)
#     451
#     452
#
# ~\Anaconda3\envs\pythondata\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype)
#    1125                          schema=schema, dtype=dtype)
#    1126         table.create()
# -> 1127         table.insert(chunksize)
#    1128         if (not name.isdigit() and not name.islower()):
#    1129             # check for potentially case sensitivity issues (GH7815)
#
# ~\Anaconda3\envs\pythondata\lib\site-packages\pandas\io\sql.py in insert(self, chunksize)
#     639
#     640                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 641                 self._execute_insert(conn, keys, chunk_iter)
#     642
#     643     def _query_iterator(self, result, chunksize, columns, coerce_float=True,
#
# ~\Anaconda3\envs\pythondata\lib\site-packages\pandas\io\sql.py in _execute_insert(self, conn, keys, data_iter)
#     614     def _execute_insert(self, conn, keys, data_iter):
#     615         data = [{k: v for k, v in zip(keys, row)} for row in data_iter]
# --> 616         conn.execute(self.insert_statement(), data)
#     617
#     618     def insert(self, chunksize=None):
#
# ~\Anaconda3\envs\pythondata\lib\site-packages\sqlalchemy\engine\base.py in execute(self, object_, *multiparams, **params)
#     986             raise exc.ObjectNotExecutableError(object_)
#     987         else:
# --> 988             return meth(self, multiparams, params)
#     989
#     990     def _execute_function(self, func, multiparams, params):
#
# ~\Anaconda3\envs\pythondata\lib\site-packages\sqlalchemy\sql\elements.py in _execute_on_connection(self, connection, multiparams, params)
#     285     def _execute_on_connection(self, connection, multiparams, params):
#     286         if self.supports_execution:
# --> 287             return connection._execute_clauseelement(self, multiparams, params)
#     288         else:
#     289             raise exc.ObjectNotExecutableError(self)
#
# ~\Anaconda3\envs\pythondata\lib\site-packages\sqlalchemy\engine\base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1105             distilled_params,
#    1106             compiled_sql,
# -> 1107             distilled_params,
#    1108         )
#    1109         if self._has_events or self.engine._has_events:
#
# ~\Anaconda3\envs\pythondata\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1246         except BaseException as e:
#    1247             self._handle_dbapi_exception(
# -> 1248                 e, statement, parameters, cursor, context
#    1249             )
#    1250
#
# ~\Anaconda3\envs\pythondata\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1464                 util.raise_from_cause(newraise, exc_info)
#    1465             elif should_wrap:
# -> 1466                 util.raise_from_cause(sqlalchemy_exception, exc_info)
#    1467             else:
#    1468                 util.reraise(*exc_info)
#
# ~\Anaconda3\envs\pythondata\lib\site-packages\sqlalchemy\util\compat.py in raise_from_cause(exception, exc_info)
#     381     exc_type, exc_value, exc_tb = exc_info
#     382     cause = exc_value if exc_value is not exception else None
# --> 383     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     384
#     385
#
# ~\Anaconda3\envs\pythondata\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     126             value.__cause__ = cause
#     127         if value.__traceback__ is not tb:
# --> 128             raise value.with_traceback(tb)
#     129         raise value
#     130
#
# ~\Anaconda3\envs\pythondata\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1222                 if not evt_handled:
#    1223                     self.dialect.do_executemany(
# -> 1224                         cursor, statement, parameters, context
#    1225                     )
#    1226             elif not parameters and context.no_parameters:
#
# ~\Anaconda3\envs\pythondata\lib\site-packages\sqlalchemy\engine\default.py in do_executemany(self, cursor, statement, parameters, context)
#     547
#     548     def do_executemany(self, cursor, statement, parameters, context=None):
# --> 549         cursor.executemany(statement, parameters)
#     550
#     551     def do_execute(self, cursor, statement, parameters, context=None):
#
# OperationalError: (sqlite3.OperationalError) table airbnb has no column named Address
# [SQL: INSERT INTO airbnb ("Name", "Address", "City", "State", "Zip", "Type", "Average Rating") VALUES (?, ?, ?, ?, ?, ?, ?)]
# [parameters: (('Private bed in home', 'Buckeye Trail, West Lake Hills, TX 78746, United States', 'West Lake Hills', 'TX', 78746.0, 'Other', 4.7), ('Lake House minutes to Downtown', 'Westlake Dr, Austin, TX 78746, United States', 'Austin', 'TX', 78746.0, 'House', 4.800000000000001), ('Modern New Apartment Close to Everything!', 'South MoPac Expressway, Austin, TX 78746, United States', 'Austin', 'TX', 78746.0, 'Apartment', 4.8500000000000005), ('Austin Waterfront Retreat', 'Bend O River Drive, Austin, TX 78746, United States', 'Austin', 'TX', 78746.0, 'House', 4.800000000000001), ("Stay at the Domain's hotest residencial property.", 'Esperanza Crossing, Austin, TX 78758, United States', 'Austin', 'TX', 78758.0, 'Condominium', 4.65), ('Studio Apt Close to Zilker/Barton Springs/360', 'Austin, TX 78746, United States', 'Austin', 'TX', 78746.0, 'Apartment', 4.95), ('Comfort & Convenience in Backyard Studio w/Kitchen', 'Munson Street, Austin, TX 78721, United States', 'Austin', 'TX', 78721.0, 'Guesthouse', 4.8500000000000005), ('Private Room in The Austin Oasis House Lake Travis', 'Sutton Drive, Austin, TX 78734, United States', 'Austin', 'TX', 78734.0, 'House', 5.0)  ... displaying 10 of 100937 total bound parameter sets ...  ('MODERN FREMONT 2bdrm  VIEW!', 'Whitman Avenue North, Seattle, WA 98103, United States', 'Seattle', 'WA', 98103.0, 'Apartment', 4.4), ('Beautiful Ravenna Hardwoods UW', 'Northeast 73rd Street, Seattle, WA 98115, United States', 'Seattle', 'WA', 98115.0, 'House', 4.800000000000001))]
# (Background on this error at: http://sqlalche.me/e/e3q8)

# %%
data = engine2.execute("SELECT * FROM airbnb WHERE State == 'WA'")

#for record in data:
 #      print(record)

# %% [markdown]
# *****************
