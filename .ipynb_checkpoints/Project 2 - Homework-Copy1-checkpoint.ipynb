# %%
import pandas as pd
from sqlalchemy import create_engine
import requests
import warnings
warnings.filterwarnings('ignore')

# %%
f = "airbnb-listings.csv"
f_df = pd.read_csv(f, delimiter=';', encoding = 'latin-1')
f_df.head()
# Out:
#          ID                            Listing Url       Scrape ID  \
# 0   2501888   https://www.airbnb.com/rooms/2501888  20170306202425
# 1    377609    https://www.airbnb.com/rooms/377609  20170306202425
# 2  15643010  https://www.airbnb.com/rooms/15643010  20170306202425
# 3   2236988   https://www.airbnb.com/rooms/2236988  20170306202425
# 4  14788276  https://www.airbnb.com/rooms/14788276  20170306202425
#
#   Last Scraped                                               Name  \
# 0   2017-03-07                                Private bed in home
# 1   2017-03-07                     Lake House minutes to Downtown
# 2   2017-03-07          Modern New Apartment Close to Everything!
# 3   2017-03-07                          Austin Waterfront Retreat
# 4   2017-03-07  Stay at the Domain's hotest residencial property.
#
#                                              Summary  \
# 0  Sofa bed in the media room on the first floor....
# 1                                                NaN
# 2  Close to the Barton Creek Greenbelt, S Lamar, ...
# 3  Magnificent Austin waterfront home on Barton C...
# 4  Find indulgence the moment you enter the bouti...
#
#                                                Space  \
# 0  Modernist home with a strong influence from MC...
# 1  Located just 7 minutes to Downtown, and 4 minu...
# 2                                                NaN
# 3  Retreat within the city of Austin.  12 minutes...
# 4                                                NaN
#
#                                          Description Experiences Offered  \
# 0  Sofa bed in the media room on the first floor....                none
# 1  Located just 7 minutes to Downtown, and 4 minu...                none
# 2  Close to the Barton Creek Greenbelt, S Lamar, ...                none
# 3  Magnificent Austin waterfront home on Barton C...                none
# 4  Find indulgence the moment you enter the bouti...                none
#
#                                Neighborhood Overview  \
# 0  Upscale area of West Lake Hills on a bluff ove...
# 1                                                NaN
# 2                                                NaN
# 3  Quiet neighborhood tucked away in Austin.  Min...
# 4                                                NaN
#
#                          ...                          \
# 0                        ...
# 1                        ...
# 2                        ...
# 3                        ...
# 4                        ...
#
#   Review Scores Communication Review Scores Location Review Scores Value  \
# 0                        10.0                    9.0                 9.0
# 1                        10.0                   10.0                 9.0
# 2                        10.0                   10.0                10.0
# 3                        10.0                   10.0                10.0
# 4                        10.0                   10.0                 9.0
#
#   License Jurisdiction Names Cancellation Policy  \
# 0     NaN                NaN            flexible
# 1     NaN                NaN              strict
# 2     NaN                NaN            moderate
# 3     NaN                NaN              strict
# 4     NaN                NaN            moderate
#
#   Calculated host listings count Reviews per Month  \
# 0                              1              2.42
# 1                              1              0.54
# 2                              1              1.86
# 3                              1              0.21
# 4                              1              0.69
#
#                      Geolocation  \
# 0  30.2863434604, -97.8104775775
# 1  30.3028051776, -97.7942255855
# 2  30.2521539737, -97.7995481364
# 3   30.2752712576, -97.843114474
# 4  30.4001335924, -97.7241364202
#
#                                             Features
# 0  Host Has Profile Pic,Host Identity Verified,Is...
# 1  Host Has Profile Pic,Host Identity Verified,Is...
# 2  Host Has Profile Pic,Host Identity Verified,Is...
# 3             Host Has Profile Pic,Is Location Exact
# 4             Host Has Profile Pic,Is Location Exact
#
# [5 rows x 89 columns]

# %%
f_df.columns
# Out:
# Index(['ID', 'Listing Url', 'Scrape ID', 'Last Scraped', 'Name', 'Summary',
#        'Space', 'Description', 'Experiences Offered', 'Neighborhood Overview',
#        'Notes', 'Transit', 'Access', 'Interaction', 'House Rules',
#        'Thumbnail Url', 'Medium Url', 'Picture Url', 'XL Picture Url',
#        'Host ID', 'Host URL', 'Host Name', 'Host Since', 'Host Location',
#        'Host About', 'Host Response Time', 'Host Response Rate',
#        'Host Acceptance Rate', 'Host Thumbnail Url', 'Host Picture Url',
#        'Host Neighbourhood', 'Host Listings Count',
#        'Host Total Listings Count', 'Host Verifications', 'Street',
#        'Neighbourhood', 'Neighbourhood Cleansed',
#        'Neighbourhood Group Cleansed', 'City', 'State', 'Zipcode', 'Market',
#        'Smart Location', 'Country Code', 'Country', 'Latitude', 'Longitude',
#        'Property Type', 'Room Type', 'Accommodates', 'Bathrooms', 'Bedrooms',
#        'Beds', 'Bed Type', 'Amenities', 'Square Feet', 'Price', 'Weekly Price',
#        'Monthly Price', 'Security Deposit', 'Cleaning Fee', 'Guests Included',
#        'Extra People', 'Minimum Nights', 'Maximum Nights', 'Calendar Updated',
#        'Has Availability', 'Availability 30', 'Availability 60',
#        'Availability 90', 'Availability 365', 'Calendar last Scraped',
#        'Number of Reviews', 'First Review', 'Last Review',
#        'Review Scores Rating', 'Review Scores Accuracy',
#        'Review Scores Cleanliness', 'Review Scores Checkin',
#        'Review Scores Communication', 'Review Scores Location',
#        'Review Scores Value', 'License', 'Jurisdiction Names',
#        'Cancellation Policy', 'Calculated host listings count',
#        'Reviews per Month', 'Geolocation', 'Features'],
#       dtype='object')

# %%
n_df = f_df[[
    'Name','Host Response Rate',
    'City', 'State', 'Zipcode','Country Code', 'Property Type', 
    'Price','Number of Reviews','Review Scores Rating']].copy()
n_df.head()
# Out:
#                                                 Name  Host Response Rate  \
# 0                                Private bed in home               100.0
# 1                     Lake House minutes to Downtown               100.0
# 2          Modern New Apartment Close to Everything!               100.0
# 3                          Austin Waterfront Retreat                 NaN
# 4  Stay at the Domain's hotest residencial property.                 0.0
#
#               City State Zipcode Country Code Property Type  Price  \
# 0  West Lake Hills    TX   78746           US         Other   88.0
# 1           Austin    TX   78746           US         House  185.0
# 2           Austin    TX   78746           US     Apartment   60.0
# 3           Austin    TX   78746           US         House    NaN
# 4           Austin    TX   78758           US   Condominium  275.0
#
#    Number of Reviews  Review Scores Rating
# 0                 88                  94.0
# 1                 21                  96.0
# 2                  8                  97.0
# 3                  5                  96.0
# 4                  3                  93.0

# %%
n_df.rename(columns={'Zipcode':'Zip',
                     'Country Code':'Country',
                     'Property Type':'Category',
                     'Number of Reviews':'Review Count',
                     'Review Scores Rating':'Ratings'}, 
                 inplace=True)

# %%
d = n_df.dropna()

# %%
d['State'] = d['State'].str.upper()

# %%
d.State.unique()
#
# Out:
# array(['TX', 'MA', 'CO', 'IL', 'NY', 'CA', 'LA', 'TN', 'OR', 'WA', 'MP',
#        'DC', 'MD'], dtype=object)

# %%
d = d.set_index('Name')
d.head()
# Out:
#                                                    Host Response Rate  \
# Name
# Private bed in home                                             100.0
# Lake House minutes to Downtown                                  100.0
# Modern New Apartment Close to Everything!                       100.0
# Stay at the Domain's hotest residencial property.                 0.0
# Studio Apt Close to Zilker/Barton Springs/360                   100.0
#
#                                                               City State  \
# Name
# Private bed in home                                West Lake Hills    TX
# Lake House minutes to Downtown                              Austin    TX
# Modern New Apartment Close to Everything!                   Austin    TX
# Stay at the Domain's hotest residencial property.           Austin    TX
# Studio Apt Close to Zilker/Barton Springs/360               Austin    TX
#
#                                                      Zip Country     Category  \
# Name
# Private bed in home                                78746      US        Other
# Lake House minutes to Downtown                     78746      US        House
# Modern New Apartment Close to Everything!          78746      US    Apartment
# Stay at the Domain's hotest residencial property.  78758      US  Condominium
# Studio Apt Close to Zilker/Barton Springs/360      78746      US    Apartment
#
#                                                    Price  Review Count  \
# Name
# Private bed in home                                 88.0            88
# Lake House minutes to Downtown                     185.0            21
# Modern New Apartment Close to Everything!           60.0             8
# Stay at the Domain's hotest residencial property.  275.0             3
# Studio Apt Close to Zilker/Barton Springs/360       90.0            45
#
#                                                    Ratings
# Name
# Private bed in home                                   94.0
# Lake House minutes to Downtown                        96.0
# Modern New Apartment Close to Everything!             97.0
# Stay at the Domain's hotest residencial property.     93.0
# Studio Apt Close to Zilker/Barton Springs/360         99.0

# %%
x = "root:Abejorro9!@127.0.0.1/guestroomdata_db"
engine = create_engine(f'mysql://{x}')

# %%
d.to_sql(name='airbnb', con=engine, if_exists='append', index=False)

# %%
database_path = "db.sqlite"
engine2 = create_engine(f"sqlite:///{database_path}")
# Query All Records in the the Database
d.to_sql(name='airbnb', con=engine2, if_exists='append', index=False)
data = engine2.execute("SELECT * FROM airbnb")

#for record in data:
 #   print(record)

# %%
data = engine2.execute("SELECT * FROM airbnb WHERE State == 'WA'")

#for record in data:
 #      print(record)
